# %% [markdown]
# ## Load paths

# %%
# %store -r ROOT_DIR
# %store -r DATA_DIR
# %store -r AD_KG_DATA_DIR
# %store -r AD_KG_CYPHER_DATA_DIR
# %store -r AD_KG_CYPHER_FILE
# %store -r HGNC_DATASET_FILE
# %store -r RNASEQ_DATA_DIR
# %store -r BUILD_DIR
# %store -r DATA_BUILD_DIR
# %store -r COVID_DM_BUILD_DIR
# %store -r COVID_DM_CD_BUILD_DIR
# %store -r COVID_DM_CD_PICKLE_BUILD_DIR
# %store -r PD_DM_BUILD_DIR
# %store -r PD_DM_CD_BUILD_DIR
# %store -r PD_DM_CD_PICKLE_BUILD_DIR
# %store -r PD_DM_BEL_BUILD_DIR
# %store -r COVID_DM_BEL_BUILD_DIR
# %store -r GOAT_GENE_LISTS_BUILD_DIR
# %store -r RESULTS_DIR
# %store -r ANNOTATION_STATISTICS_DIR
# %store -r INTERFACE_DIR
# %store -r INTERFACE_ANALYSIS_DIR
# %store -r INTERFACE_ANALYSIS_GRAPHS_DIR
# %store -r INTERFACE_GOAT_UPSTREAM_ANALYSIS_DIR
# %store -r INTERFACE_GOAT_DOWNSTREAM_ANALYSIS_DIR
# %store -r INTERFACE_GOAT_UPSTREAM_AND_DOWNSTREAM_ANALYSIS_DIR
# %store -r INTERFACE_INTERSECTION_UPSTREAM_ANALYSIS_DIR
# %store -r INTERFACE_INTERSECTION_DOWNSTREAM_ANALYSIS_DIR
# %store -r INTERFACE_INTERSECTION_UPSTREAM_AND_DOWNSTREAM_ANALYSIS_DIR
# %store -r PD_DM_ANALYSIS_DIR
# %store -r PD_DM_GOAT_ANALYSIS_DIR
