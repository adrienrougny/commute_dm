# %%
# %run 0_10_load_paths.ipynb

# %%
import commute_dm.core
import commute_dm.utils

# %%
P_VALUE_THRESHOLD = 0.05

# %%
commute_dm.utils.remake_dir(GOAT_GENE_LISTS_BUILD_DIR)

# %% [markdown]
# We make the gene list files for the gene enrichment analysis:

# %%
commute_dm.core.make_goat_gene_lists(
    RNASEQ_DATA_DIR,
    GOAT_GENE_LISTS_BUILD_DIR,
    HGNC_DATASET_FILE,
    P_VALUE_THRESHOLD,
)
# Out:
# /home/rougny/research/commute/commute_dm/src/commute_dm/core.py:623: DtypeWarning: Columns (0: mirbase, 1: snornabase, 2: horde_id, 3: imgt, 4: gtrnadb) have mixed types. Specify dtype option on import or set low_memory=False.
#   hgnc_df = pandas.read_csv(hgnc_dataset_file_path, delimiter="\t")
