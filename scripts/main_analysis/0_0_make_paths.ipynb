# %%
import os.path

# %%
COVID_DM_DIR_SUFFIX = "covid_dm/"
PD_DM_DIR_SUFFIX = "pd_dm/"
AD_KG_DIR_SUFFIX = "ad_kg/"
CD_DIR_SUFFIX = "celldesigner/"
CD_PICKLE_DIR_SUFFIX = "celldesigner_pickle/"
BEL_DIR_SUFFIX = "bel/"
CYPHER_DIR_SUFFIX = "cypher/"
GMT_DIR_SUFFIX = "gmt/"

# %%
ROOT_DIR = "../../"

DATA_DIR = os.path.join(ROOT_DIR, "data/")
AD_KG_DATA_DIR = os.path.join(DATA_DIR, AD_KG_DIR_SUFFIX)
AD_KG_CYPHER_DATA_DIR = os.path.join(AD_KG_DATA_DIR, CYPHER_DIR_SUFFIX)
AD_KG_CYPHER_FILE = os.path.join(AD_KG_CYPHER_DATA_DIR, "ad_kg.cypher")
HGNC_DATASET_DIR = os.path.join(DATA_DIR, "hgnc_dataset/")
HGNC_DATASET_FILE = os.path.join(HGNC_DATASET_DIR, "hgnc_complete_dataset.csv")
RNASEQ_DATA_DIR = os.path.join(DATA_DIR, "rnaseq/")

BUILD_DIR = os.path.join(ROOT_DIR, "build/")

DATA_BUILD_DIR = os.path.join(BUILD_DIR, "data/")
COVID_DM_BUILD_DIR = os.path.join(DATA_BUILD_DIR, COVID_DM_DIR_SUFFIX)
COVID_DM_CD_BUILD_DIR = os.path.join(COVID_DM_BUILD_DIR, CD_DIR_SUFFIX)
COVID_DM_CD_PICKLE_BUILD_DIR = os.path.join(COVID_DM_BUILD_DIR, CD_PICKLE_DIR_SUFFIX)
PD_DM_BUILD_DIR = os.path.join(DATA_BUILD_DIR, PD_DM_DIR_SUFFIX)
PD_DM_CD_BUILD_DIR = os.path.join(PD_DM_BUILD_DIR, CD_DIR_SUFFIX)
PD_DM_CD_PICKLE_BUILD_DIR = os.path.join(PD_DM_BUILD_DIR, CD_PICKLE_DIR_SUFFIX)
PD_DM_BEL_BUILD_DIR = os.path.join(PD_DM_BUILD_DIR, BEL_DIR_SUFFIX)
COVID_DM_BEL_BUILD_DIR = os.path.join(COVID_DM_BUILD_DIR, BEL_DIR_SUFFIX)
GOAT_GENE_LISTS_BUILD_DIR = os.path.join(DATA_BUILD_DIR, "goat_gene_lists/")

RESULTS_DIR = os.path.join(BUILD_DIR, "results/")

ANNOTATION_STATISTICS_DIR = os.path.join(RESULTS_DIR, "annotation_statistics/")
INTERFACE_DIR = os.path.join(RESULTS_DIR, "interface/")
INTERFACE_ANALYSIS_DIR = os.path.join(INTERFACE_DIR, "analysis/")
INTERFACE_ANALYSIS_GRAPHS_DIR = os.path.join(INTERFACE_ANALYSIS_DIR, "graphs2/")
INTERFACE_GOAT_UPSTREAM_ANALYSIS_DIR = os.path.join(INTERFACE_ANALYSIS_DIR, "goat_upstream/")
INTERFACE_GOAT_DOWNSTREAM_ANALYSIS_DIR = os.path.join(INTERFACE_ANALYSIS_DIR, "goat_downstream/")
INTERFACE_GOAT_UPSTREAM_AND_DOWNSTREAM_ANALYSIS_DIR = os.path.join(INTERFACE_ANALYSIS_DIR, "goat_upstream_and_downstream/")
INTERFACE_INTERSECTION_UPSTREAM_ANALYSIS_DIR = os.path.join(INTERFACE_ANALYSIS_DIR, "intersection_upstream/")
INTERFACE_INTERSECTION_DOWNSTREAM_ANALYSIS_DIR = os.path.join(INTERFACE_ANALYSIS_DIR, "intersection_downstream/")
INTERFACE_INTERSECTION_UPSTREAM_AND_DOWNSTREAM_ANALYSIS_DIR = os.path.join(INTERFACE_ANALYSIS_DIR, "intersection_upstream_and_downstream/")
PD_DM_ANALYSIS_DIR = os.path.join(RESULTS_DIR, PD_DM_DIR_SUFFIX)
PD_DM_GOAT_ANALYSIS_DIR = os.path.join(PD_DM_ANALYSIS_DIR, "goat/")

# %%
# %store ROOT_DIR
# %store DATA_DIR
# %store AD_KG_DATA_DIR
# %store AD_KG_CYPHER_DATA_DIR
# %store AD_KG_CYPHER_FILE
# %store HGNC_DATASET_FILE
# %store RNASEQ_DATA_DIR
# %store BUILD_DIR
# %store DATA_BUILD_DIR
# %store COVID_DM_BUILD_DIR
# %store COVID_DM_CD_BUILD_DIR
# %store COVID_DM_CD_PICKLE_BUILD_DIR
# %store PD_DM_BUILD_DIR
# %store PD_DM_CD_BUILD_DIR
# %store PD_DM_CD_PICKLE_BUILD_DIR
# %store PD_DM_BEL_BUILD_DIR
# %store COVID_DM_BEL_BUILD_DIR
# %store GOAT_GENE_LISTS_BUILD_DIR
# %store RESULTS_DIR
# %store ANNOTATION_STATISTICS_DIR
# %store INTERFACE_DIR
# %store INTERFACE_ANALYSIS_DIR
# %store INTERFACE_ANALYSIS_GRAPHS_DIR
# %store INTERFACE_GOAT_UPSTREAM_ANALYSIS_DIR
# %store INTERFACE_GOAT_DOWNSTREAM_ANALYSIS_DIR
# %store INTERFACE_GOAT_UPSTREAM_AND_DOWNSTREAM_ANALYSIS_DIR
# %store INTERFACE_INTERSECTION_UPSTREAM_ANALYSIS_DIR
# %store INTERFACE_INTERSECTION_DOWNSTREAM_ANALYSIS_DIR
# %store INTERFACE_INTERSECTION_UPSTREAM_AND_DOWNSTREAM_ANALYSIS_DIR
# %store PD_DM_ANALYSIS_DIR
# %store PD_DM_GOAT_ANALYSIS_DIR
# Out:
# Stored 'ROOT_DIR' (str)
# Stored 'DATA_DIR' (str)
# Stored 'AD_KG_DATA_DIR' (str)
# Stored 'AD_KG_CYPHER_DATA_DIR' (str)
# Stored 'AD_KG_CYPHER_FILE' (str)
# Stored 'HGNC_DATASET_FILE' (str)
# Stored 'RNASEQ_DATA_DIR' (str)
# Stored 'BUILD_DIR' (str)
# Stored 'DATA_BUILD_DIR' (str)
# Stored 'COVID_DM_BUILD_DIR' (str)
# Stored 'COVID_DM_CD_BUILD_DIR' (str)
# Stored 'COVID_DM_CD_PICKLE_BUILD_DIR' (str)
# Stored 'PD_DM_BUILD_DIR' (str)
# Stored 'PD_DM_CD_BUILD_DIR' (str)
# Stored 'PD_DM_CD_PICKLE_BUILD_DIR' (str)
# Stored 'PD_DM_BEL_BUILD_DIR' (str)
# Stored 'COVID_DM_BEL_BUILD_DIR' (str)
# Stored 'GOAT_GENE_LISTS_BUILD_DIR' (str)
# Stored 'RESULTS_DIR' (str)
# Stored 'ANNOTATION_STATISTICS_DIR' (str)
# Stored 'INTERFACE_DIR' (str)
# Stored 'INTERFACE_ANALYSIS_DIR' (str)
# Stored 'INTERFACE_ANALYSIS_GRAPHS_DIR' (str)
# Stored 'INTERFACE_GOAT_UPSTREAM_ANALYSIS_DIR' (str)
# Stored 'INTERFACE_GOAT_DOWNSTREAM_ANALYSIS_DIR' (str)
# ...
