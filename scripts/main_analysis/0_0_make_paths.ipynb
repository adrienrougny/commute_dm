# %%
import pathlib

# %%
COVID_DM_DIR_SUFFIX = "covid_dm/"
PD_DM_DIR_SUFFIX = "pd_dm/"
AD_KG_DIR_SUFFIX = "ad_kg/"
COVID_KG_DIR_SUFFIX = "covid_kg/"
PD_KG_DIR_SUFFIX = "pd_kg/"
CD_DIR_SUFFIX = "celldesigner/"
CD_PICKLE_DIR_SUFFIX = "celldesigner_pickle/"
BEL_DIR_SUFFIX = "bel/"
CYPHER_DIR_SUFFIX = "cypher/"
GMT_DIR_SUFFIX = "gmt/"

# %%
ROOT_DIR = pathlib.Path("../../")

DATA_DIR = ROOT_DIR / "data/"
MAPS_DATA_DIR = DATA_DIR / "maps/"
COVID_DM_CD_DATA_DIR = MAPS_DATA_DIR / COVID_DM_DIR_SUFFIX / CD_DIR_SUFFIX
PD_DM_CD_DATA_DIR = MAPS_DATA_DIR / PD_DM_DIR_SUFFIX / CD_DIR_SUFFIX
AD_KG_CYPHER_DATA_FILE = (
    DATA_DIR / AD_KG_DIR_SUFFIX / CYPHER_DIR_SUFFIX / "ad_kg.cypher"
)
PD_KG_CYPHER_DATA_FILE = (
    DATA_DIR / PD_KG_DIR_SUFFIX / CYPHER_DIR_SUFFIX / "pd_kg.cypher"
)
COVID_KG_CYPHER_DATA_FILE = (
    DATA_DIR / COVID_KG_DIR_SUFFIX / CYPHER_DIR_SUFFIX / "covid_kg.cypher"
)
HGNC_DATA_DIR = DATA_DIR / "hgnc_dataset/"
HGNC_DATA_FILE = HGNC_DATA_DIR / "hgnc_complete_dataset.csv"
RNASEQ_DATA_DIR = DATA_DIR / "rnaseq/"

BUILD_DIR = ROOT_DIR / "build/"
MAPS_BUILD_DIR = BUILD_DIR / "maps/"
COVID_DM_BEL_BUILD_DIR = MAPS_BUILD_DIR / COVID_DM_DIR_SUFFIX / BEL_DIR_SUFFIX
PD_DM_BEL_BUILD_DIR = MAPS_BUILD_DIR / PD_DM_DIR_SUFFIX / BEL_DIR_SUFFIX
GOAT_GENE_LISTS_BUILD_DIR = BUILD_DIR / "goat_gene_lists/"

RESULTS_DIR = BUILD_DIR / "results/"

ANNOTATION_STATISTICS_DIR = RESULTS_DIR / "annotation_statistics/"
INTERFACE_DIR = RESULTS_DIR / "interface/"
INTERFACE_ANALYSIS_DIR = INTERFACE_DIR / "analysis/"
INTERFACE_ANALYSIS_GRAPHS_DIR = INTERFACE_ANALYSIS_DIR / "graphs/"
INTERFACE_GOAT_UPSTREAM_ANALYSIS_DIR = INTERFACE_ANALYSIS_DIR / "goat_upstream/"
INTERFACE_GOAT_DOWNSTREAM_ANALYSIS_DIR = INTERFACE_ANALYSIS_DIR / "goat_downstream/"
INTERFACE_GOAT_UPSTREAM_AND_DOWNSTREAM_ANALYSIS_DIR = (
    INTERFACE_ANALYSIS_DIR / "goat_upstream_and_downstream/"
)
INTERFACE_INTERSECTION_UPSTREAM_ANALYSIS_DIR = (
    INTERFACE_ANALYSIS_DIR / "intersection_upstream/"
)
INTERFACE_INTERSECTION_DOWNSTREAM_ANALYSIS_DIR = (
    INTERFACE_ANALYSIS_DIR / "intersection_downstream/"
)
INTERFACE_INTERSECTION_UPSTREAM_AND_DOWNSTREAM_ANALYSIS_DIR = (
    INTERFACE_ANALYSIS_DIR / "intersection_upstream_and_downstream/"
)
PD_DM_ANALYSIS_DIR = RESULTS_DIR / PD_DM_DIR_SUFFIX
PD_DM_GOAT_ANALYSIS_DIR = PD_DM_ANALYSIS_DIR / "goat/"

# %%
for name, value in list(locals().items()):
    if name.isupper() and isinstance(value, pathlib.Path):
        get_ipython().run_line_magic("store", name)
# Out:
# Stored 'ROOT_DIR' (PosixPath)
# Stored 'DATA_DIR' (PosixPath)
# Stored 'MAPS_DATA_DIR' (PosixPath)
# Stored 'COVID_DM_CD_DATA_DIR' (PosixPath)
# Stored 'PD_DM_CD_DATA_DIR' (PosixPath)
# Stored 'AD_KG_DATA_DIR' (PosixPath)
# Stored 'AD_KG_CYPHER_DATA_DIR' (PosixPath)
# Stored 'AD_KG_CYPHER_DATA_FILE' (PosixPath)
# Stored 'HGNC_DATA_DIR' (PosixPath)
# Stored 'HGNC_DATA_FILE' (PosixPath)
# Stored 'RNASEQ_DATA_DIR' (PosixPath)
# Stored 'BUILD_DIR' (PosixPath)
# Stored 'MAPS_BUILD_DIR' (PosixPath)
# Stored 'COVID_DM_BEL_BUILD_DIR' (PosixPath)
# Stored 'PD_DM_BEL_BUILD_DIR' (PosixPath)
# Stored 'GOAT_GENE_LISTS_BUILD_DIR' (PosixPath)
# Stored 'RESULTS_DIR' (PosixPath)
# Stored 'ANNOTATION_STATISTICS_DIR' (PosixPath)
# Stored 'INTERFACE_DIR' (PosixPath)
# Stored 'INTERFACE_ANALYSIS_DIR' (PosixPath)
# Stored 'INTERFACE_ANALYSIS_GRAPHS_DIR' (PosixPath)
# Stored 'INTERFACE_GOAT_UPSTREAM_ANALYSIS_DIR' (PosixPath)
# Stored 'INTERFACE_GOAT_DOWNSTREAM_ANALYSIS_DIR' (PosixPath)
# ...
