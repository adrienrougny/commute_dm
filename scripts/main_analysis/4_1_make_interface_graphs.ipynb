# %%
# %run 0_1_load_paths.ipynb

# %%
import commute_dm.core
import commute_dm.utils
import credentials
import momapy_kb.lpg.backends.neo4j
import momapy_kb.lpg.session

# %%
backend = momapy_kb.lpg.backends.neo4j.Neo4jBackend(
    hostname=credentials.NEO4J_URI,
    username=credentials.NEO4J_USERNAME,
    password=credentials.NEO4J_PASSWORD,
    notifications_min_severity="off",
)
session = momapy_kb.lpg.session.Session(backend)

# %%
MAX_LEVELS = [2, 3, 4, 5, 6]
MIN_N_NODES = 5

# %% [markdown]
# We compute the interface

# %%
interface = commute_dm.core.get_interface(session)

# %%
commute_dm.utils.remake_dir(INTERFACE_ANALYSIS_GRAPHS_DIR)

# %% [markdown]
# We make and render the graphs upstream and downstream of the interface:

# %%
commute_dm.core.make_and_render_igs_from_interface(
    session=session,
    interface=interface,
    output_dir_path=INTERFACE_ANALYSIS_GRAPHS_DIR,
    max_levels=MAX_LEVELS,
    covid_nodes_color="lightblue",
    pd_nodes_color="lightgreen",
    common_nodes_color="goldenrod",
    interface_nodes_color="red",
    min_n_nodes=MIN_N_NODES,
)
# Out:
# [#DDAC]  _: <CONNECTION> error: Failed to read from defunct connection IPv4Address(('localhost', 7687)) (ResolvedIPv4Address(('127.0.0.1', 7687))): OSError('No data')
# Transaction failed and will be retried in 0.824352872893231s (Failed to read from defunct connection IPv4Address(('localhost', 7687)) (ResolvedIPv4Address(('127.0.0.1', 7687))))
# Transaction failed and will be retried in 1.6477488984521111s (Couldn't connect to localhost:7687 (resolved to ('[::1]:7687', '127.0.0.1:7687')):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 111] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 111] Connection refused))
# Transaction failed and will be retried in 3.545436005005875s (Couldn't connect to localhost:7687 (resolved to ('[::1]:7687', '127.0.0.1:7687')):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 111] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 111] Connection refused))
# Transaction failed and will be retried in 8.532579749323215s (Couldn't connect to localhost:7687 (resolved to ('[::1]:7687', '127.0.0.1:7687')):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 111] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 111] Connection refused))
# Transaction failed and will be retried in 14.337911896295589s (Couldn't connect to localhost:7687 (resolved to ('[::1]:7687', '127.0.0.1:7687')):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 111] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 111] Connection refused))
# Transaction failed and will be retried in 27.931407202900072s (Couldn't connect to localhost:7687 (resolved to ('[::1]:7687', '127.0.0.1:7687')):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 111] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 111] Connection refused))
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/research/commute/commute_dm/.venv/lib/python3.12/site-packages/neo4j/_async_compat/network/_bolt_socket.py:512, in BoltSocketBase._connect_secure(cls, resolved_address, timeout, deadline, keep_alive, ssl_context)
#     511 log.debug("[#0000]  C: <OPEN> %s", resolved_address)
# --> 512 s.connect(resolved_address)
#     513 s.settimeout(t)
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# File ~/research/commute/commute_dm/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_bolt_socket.py:329, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     328 try:
# --> 329     s = cls._connect_secure(
#     330         resolved_address,
#     331         tcp_timeout,
#     332         deadline,
#     333         keep_alive,
#     334         ssl_context,
#     335     )
#     336     agreed_version = s._handshake(resolved_address, deadline)
#
# File ~/research/commute/commute_dm/.venv/lib/python3.12/site-packages/neo4j/_async_compat/network/_bolt_socket.py:523, in BoltSocketBase._connect_secure(cls, resolved_address, timeout, deadline, keep_alive, ssl_context)
#     522 if isinstance(error, OSError):
# --> 523     raise ServiceUnavailable(
#     524         "Failed to establish connection to "
#     525         f"{resolved_address!r} (reason {error})"
#     526     ) from error
#     527 raise
#
# ServiceUnavailable: Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 111] Connection refused)
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 commute_dm.core.make_and_render_igs_from_interface(
#       2     session=session,
#       3     interface=interface,
#       4     output_dir_path=INTERFACE_ANALYSIS_GRAPHS_DIR,
#
# File ~/research/commute/commute_dm/src/commute_dm/core.py:387, in make_and_render_igs_from_interface(session, interface, output_dir_path, max_levels, min_n_nodes, covid_nodes_color, pd_nodes_color, common_nodes_color, interface_nodes_color)
#     378     if map_layouts:
#     379         momapy.rendering.core.render_layout_elements(
#     380             layout_elements=map_layouts,
#     381             file_path=output_file_path,
#    (...)    385             to_top_left=False,
#     386         )
# --> 387 _remove_interface_from_db(session)
#
# File ~/research/commute/commute_dm/src/commute_dm/core.py:279, in _remove_interface_from_db(session)
#     266 session.execute_query(
#     267     """
#     268     MATCH
#    (...)    275     """
#     276 )
#     277 # Now the dummy subgraph is isolated from the rest of the graph along
#     278 # outgoing edges, so the structural cleanup is safe.
# --> 279 session.execute_query(
#     280     """
#     281     MATCH
#     282         (collection:Collection {name: "DUMMY_MAP"})-[:HAS_ENTRY]->(entry)-[:HAS_OBJ]->(map:CellDesignerMap)
#     283     OPTIONAL MATCH (map)-[*0..]->(descendant)
#     284     DETACH DELETE collection, entry, map, descendant
#     285     """
#     286 )
#
# File ~/code/momapy_kb/src/momapy_kb/lpg/session.py:211, in Session.execute_query(self, query, params)
#     197 def execute_query(
#     198     self,
#     199     query: str,
#     200     params: dict | None = None,
#     201 ) -> list[dict]:
#     202     """Execute a Cypher query against the database.
#     203
#     204     Args:
#    (...)    209         Query results as a list of dicts.
#     210     """
# --> 211     return self._session.execute_query(query, params=params)
#
# File ~/code/fieldz_kb/src/fieldz_kb/lpg/session.py:75, in Session.execute_query(self, query, params)
#      61 def execute_query(
#      62     self,
#      63     query: str,
#      64     params: dict | None = None,
#      65 ) -> list[dict]:
#      66     """Execute a Cypher query against the database.
#      67
#      68     Args:
#    (...)     73         Query results as a list of dicts.
#      74     """
# ---> 75     return self._pylpg_session.execute_query(
#      76         query, parameters=params
#      77     )
#
# File ~/code/pylpg/src/pylpg/session.py:59, in Session.execute_query(self, cypher, parameters, resolve_nodes)
#      38 def execute_query(
#      39     self,
#      40     cypher: str,
#      41     parameters: dict[str, typing.Any] | None = None,
#      42     resolve_nodes: bool = False,
#      43 ) -> list[dict[str, typing.Any]]:
#      44     """Execute a raw Cypher query.
#      45
#      46     When `resolve_nodes` is True, any driver node objects in the
#    (...)     57         ```
#      58     """
# ---> 59     results = self._backend.execute_query(cypher, parameters)
#      60     if resolve_nodes:
#      61         return [self._hydrate_row(row) for row in results]
#
# File ~/code/pylpg/src/pylpg/backend/neo4j.py:54, in Neo4jBackend.execute_query(self, cypher, parameters, transaction)
#      52     records = list(result)
#      53 else:
# ---> 54     records, summary, keys = self._driver.execute_query(
#      55         cypher, parameters_=parameters or {}, database_=self._database
#      56     )
#      57 return [dict(zip(keys, record.values())) for record in records]
#
# File ~/research/commute/commute_dm/.venv/lib/python3.12/site-packages/neo4j/_sync/driver.py:946, in Driver.execute_query(self, query_, parameters_, routing_, database_, impersonated_user_, bookmark_manager_, auth_, result_transformer_, **kwargs)
#     942     raise ValueError(
#     943         f"Invalid routing control value: {routing_!r}"
#     944     )
#     945 with session._pipelined_begin:
# --> 946     return session._run_transaction(
#     947         access_mode,
#     948         TelemetryAPI.DRIVER,
#     949         work,
#     950         (query_str, parameters, result_transformer_),
#     951         {},
#     952     )
#
# File ~/research/commute/commute_dm/.venv/lib/python3.12/site-packages/neo4j/_sync/work/session.py:584, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     579         raise
#     581 if errors:
#     582     # TODO: 7.0 - when Python 3.11+ is the minimum,
#     583     #             use exception groups
# --> 584     raise errors[-1]
#     585 else:
#     586     raise ServiceUnavailable("Transaction failed")
#
# File ~/research/commute/commute_dm/.venv/lib/python3.12/site-packages/neo4j/_sync/work/session.py:532, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     530 while True:
#     531     try:
# --> 532         self._open_transaction(
#     533             tx_cls=ManagedTransaction,
#     534             api=None if telemetry_sent else api,
#     535             access_mode=access_mode,
#     536             metadata=metadata,
#     537             timeout=timeout,
#     538             api_success_cb=api_success_cb,
#     539         )
#     540         assert isinstance(self._transaction, ManagedTransaction)
#     541         tx = self._transaction
#
# File ~/research/commute/commute_dm/.venv/lib/python3.12/site-packages/neo4j/_sync/work/session.py:398, in Session._open_transaction(self, tx_cls, access_mode, api, metadata, timeout, api_success_cb)
#     388 def _open_transaction(
#     389     self,
#     390     *,
#    (...)    396     api_success_cb: t.Callable[[dict], None] | None = None,
#     397 ) -> None:
# --> 398     self._connect(access_mode=access_mode)
#     399     assert self._connection is not None
#     400     if api is not None:
#
# File ~/research/commute/commute_dm/.venv/lib/python3.12/site-packages/neo4j/_sync/work/session.py:126, in Session._connect(self, access_mode, **acquire_kwargs)
#     124     access_mode = self._config.default_access_mode
#     125 try:
# --> 126     super()._connect(
#     127         access_mode, auth=self._config.auth, **acquire_kwargs
#     128     )
#     129 except asyncio.CancelledError:
#     130     self._handle_cancellation(message="_connect")
#
# File ~/research/commute/commute_dm/.venv/lib/python3.12/site-packages/neo4j/_sync/work/workspace.py:181, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     171 acquire_kwargs_ = {
#     172     "access_mode": access_mode,
#     173     "timeout": acquisition_deadline,
#    (...)    178     "database_callback": self._make_db_resolution_callback(),
#     179 }
#     180 acquire_kwargs_.update(acquire_kwargs)
# --> 181 self._connection = self._pool.acquire(**acquire_kwargs_)
#     182 if (
#     183     target_db.guessed
#     184     and not self._pinned_database
#    (...)    188     # support SSR.
#     189     # => we need to fall back to explicit home database resolution
#     190     log.debug(
#     191         "[#0000]  _: <WORKSPACE> detected ssr support race; "
#     192         "falling back to explicit home database resolution",
#     193     )
#
# File ~/research/commute/commute_dm/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:678, in BoltPool.acquire(self, access_mode, timeout, database, bookmarks, auth, liveness_check_timeout, unprepared, database_callback)
#     671 deadline = acquisition_timeout_to_deadline(timeout)
#     672 log.debug(
#     673     "[#0000]  _: <POOL> acquire direct connection, "
#     674     "access_mode=%r, database=%r",
#     675     access_mode,
#     676     database,
#     677 )
# --> 678 return self._acquire(
#     679     self.address, auth, deadline, liveness_check_timeout, unprepared
#     680 )
#
# File ~/research/commute/commute_dm/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:418, in IOPool._acquire(self, address, auth, deadline, liveness_check_timeout, unprepared)
#     413             raise ConnectionAcquisitionTimeoutError(
#     414                 "failed to obtain a connection from the pool within "
#     415                 f"{deadline.original_timeout!r}s (timeout)"
#     416             )
#     417 log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 418 return connection_creator()
#
# File ~/research/commute/commute_dm/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:231, in IOPool._acquire_new_later.<locals>.connection_creator()
#     229 try:
#     230     try:
# --> 231         connection = self.opener(
#     232             address, auth or self.pool_config.auth, deadline
#     233         )
#     234     except ServiceUnavailable:
#     235         self.deactivate(address)
#
# File ~/research/commute/commute_dm/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:638, in BoltPool.open.<locals>.opener(addr, auth_manager, deadline)
#     637 def opener(addr, auth_manager, deadline):
# --> 638     return Bolt.open(
#     639         addr,
#     640         auth_manager=auth_manager,
#     641         deadline=deadline,
#     642         routing_context=None,
#     643         pool_config=pool_config,
#     644     )
#
# File ~/research/commute/commute_dm/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_bolt.py:368, in Bolt.open(address, auth_manager, deadline, routing_context, pool_config)
#     365 if deadline is None:
#     366     deadline = Deadline(None)
# --> 368 s, protocol_version = BoltSocket.connect(
#     369     address,
#     370     tcp_timeout=pool_config.connection_timeout,
#     371     deadline=deadline,
#     372     custom_resolver=pool_config.resolver,
#     373     ssl_context=pool_config.get_ssl_context(),
#     374     keep_alive=pool_config.keep_alive,
#     375 )
#     377 pool_config.protocol_version = protocol_version
#     378 protocol_handlers = Bolt.protocol_handlers
#
# File ~/research/commute/commute_dm/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_bolt_socket.py:380, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     378 else:
#     379     error_strs = "\n".join(map(str, errors))
# --> 380     raise ServiceUnavailable(
#     381         f"Couldn't connect to {address} (resolved to {address_strs}):"
#     382         f"\n{error_strs}"
#     383     ) from errors[0]
#
# ServiceUnavailable: Couldn't connect to localhost:7687 (resolved to ('[::1]:7687', '127.0.0.1:7687')):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 111] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 111] Connection refused)
