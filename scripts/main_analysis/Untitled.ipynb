# %%
class_name_to_bel_namespaces = {
    "Drug": [
        "drugbank",
        "obo.chebi",
        "pubchem.compound",
        "mesh",
        "ncit",
    ],
    "GenericProtein": [
        "uniprot",
        "pr",
        "interpro",
        "mesh",
        "ncbiprotein", # to check with Heval and Alpha
    ],
    "Receptor": [
        "uniprot",
        "pr",
        "interpro",
        "mesh",
        "ncbiprotein", # to check with Heval and Alpha
    ],
    "IonChannel": [
        "uniprot",
        "pr",
        "interpro",
        "mesh",
        "ncbiprotein", # to check with Heval and Alpha
    ],
    "TruncatedProtein": [
        "uniprot",
        "pr",
        "interpro",
        "mesh",
        "ncbiprotein", # to check with Heval and Alpha
    ],
    "SimpleMolecule": [
        "obo.chebi",
        "pubchem.compound",
        "mesh",
        "ncit",
    ],
    "Ion": [
        "obo.chebi",
        "pubchem.compound",
        "mesh",
        "ncit",
    ],
    "Phenotype": [
        "doid",
        "mondo",
        "hp",
        "snomedct",
        "obo.go",
        "mesh",
        "wikipathways",
        "reactome",
        "omim", # to check with Heval and Alpha
    ],
    "Gene": [
        "hgnc.symbol",
        "mgi",
        "rgd",
        "ncbigene",
        "hgnc.group",
    ],
    "RNA": [
        "hgnc.symbol",
        "mgi",
        "rgd",
        "ncbigene",
        "hgnc.group",
        "refseq", # to check with Heval and Alpha
    ],
    "Complex": [
        "obo.go",
        "pr",
        "mesh",
        "cl",
        "clo",
        "uniprot", # to check with Heval and Alpha
        "ncbiprotein", # to check with Heval and Alpha
    ],
    "Compartment": [
        "obo.go",
        "mesh",
        "cl",
        "clo",
        "uberon",
        "ncit"
    ],
    "Degraded": [],
}

# %%
for class_name, bel_namespaces in class_name_to_bel_namespaces.items():
    print(class_name)
    for i, bel_namespace_1 in enumerate(bel_namespaces):
        for j, bel_namespace_2 in enumerate(bel_namespaces[i+1:]):
            print(f"{bel_namespace_2}, {bel_namespace_1}")
# Out:
# Drug
# obo.chebi, drugbank
# pubchem.compound, drugbank
# mesh, drugbank
# ncit, drugbank
# pubchem.compound, obo.chebi
# mesh, obo.chebi
# ncit, obo.chebi
# mesh, pubchem.compound
# ncit, pubchem.compound
# ncit, mesh
# GenericProtein
# pr, uniprot
# interpro, uniprot
# mesh, uniprot
# ncbiprotein, uniprot
# interpro, pr
# mesh, pr
# ncbiprotein, pr
# mesh, interpro
# ncbiprotein, interpro
# ncbiprotein, mesh
# Receptor
# pr, uniprot
# interpro, uniprot
# mesh, uniprot
# ncbiprotein, uniprot
# interpro, pr
# mesh, pr
# ncbiprotein, pr
# mesh, interpro
# ncbiprotein, interpro
# ncbiprotein, mesh
# IonChannel
# pr, uniprot
# interpro, uniprot
# mesh, uniprot
# ncbiprotein, uniprot
# interpro, pr
# mesh, pr
# ncbiprotein, pr
# mesh, interpro
# ncbiprotein, interpro
# ncbiprotein, mesh
# TruncatedProtein
# pr, uniprot
# interpro, uniprot
# mesh, uniprot
# ncbiprotein, uniprot
# interpro, pr
# mesh, pr
# ncbiprotein, pr
# mesh, interpro
# ncbiprotein, interpro
# ncbiprotein, mesh
# SimpleMolecule
# pubchem.compound, obo.chebi
# mesh, obo.chebi
# ncit, obo.chebi
# mesh, pubchem.compound
# ncit, pubchem.compound
# ncit, mesh
# Ion
# pubchem.compound, obo.chebi
# mesh, obo.chebi
# ncit, obo.chebi
# mesh, pubchem.compound
# ncit, pubchem.compound
# ncit, mesh
# Phenotype
# mondo, doid
# hp, doid
# snomedct, doid
# obo.go, doid
# mesh, doid
# wikipathways, doid
# reactome, doid
# omim, doid
# hp, mondo
# snomedct, mondo
# obo.go, mondo
# mesh, mondo
# wikipathways, mondo
# reactome, mondo
# omim, mondo
# snomedct, hp
# obo.go, hp
# mesh, hp
# wikipathways, hp
# reactome, hp
# omim, hp
# obo.go, snomedct
# mesh, snomedct
# wikipathways, snomedct
# reactome, snomedct
# omim, snomedct
# mesh, obo.go
# wikipathways, obo.go
# reactome, obo.go
# omim, obo.go
# wikipathways, mesh
# reactome, mesh
# omim, mesh
# reactome, wikipathways
# omim, wikipathways
# omim, reactome
# Gene
# mgi, hgnc.symbol
# rgd, hgnc.symbol
# ncbigene, hgnc.symbol
# hgnc.group, hgnc.symbol
# rgd, mgi
# ncbigene, mgi
# hgnc.group, mgi
# ncbigene, rgd
# hgnc.group, rgd
# hgnc.group, ncbigene
# RNA
# mgi, hgnc.symbol
# rgd, hgnc.symbol
# ncbigene, hgnc.symbol
# hgnc.group, hgnc.symbol
# refseq, hgnc.symbol
# rgd, mgi
# ncbigene, mgi
# hgnc.group, mgi
# refseq, mgi
# ncbigene, rgd
# hgnc.group, rgd
# refseq, rgd
# hgnc.group, ncbigene
# refseq, ncbigene
# refseq, hgnc.group
# Complex
# pr, obo.go
# mesh, obo.go
# cl, obo.go
# clo, obo.go
# uniprot, obo.go
# ncbiprotein, obo.go
# mesh, pr
# cl, pr
# clo, pr
# uniprot, pr
# ncbiprotein, pr
# cl, mesh
# clo, mesh
# uniprot, mesh
# ncbiprotein, mesh
# clo, cl
# uniprot, cl
# ncbiprotein, cl
# uniprot, clo
# ncbiprotein, clo
# ncbiprotein, uniprot
# Compartment
# mesh, obo.go
# cl, obo.go
# clo, obo.go
# uberon, obo.go
# ncit, obo.go
# cl, mesh
# clo, mesh
# uberon, mesh
# ncit, mesh
# clo, cl
# uberon, cl
# ncit, cl
# uberon, clo
# ncit, clo
# ncit, uberon
# Degraded
